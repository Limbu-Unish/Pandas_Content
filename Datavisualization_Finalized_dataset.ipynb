# %%
#importing pandas, numpy and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib basics

# %%
#importing the dataset
df = pd.read_csv('Finalized_dataset.csv')
df.columns
# Out:
# Index(['Rank', 'Peak', 'All Time Peak', 'Actual_Gross',
#        'Adjusted gross (in 2022 dollars)', 'Artist', 'Tour title', 'Shows',
#        'Average gross', 'Reference', 'Actual_Gross_with_VAT', 'Starting_Year',
#        'Ending_Year'],
#       dtype='object')

# %%
Artist_name = df['Artist']
Actual_gross = df['Actual_Gross']

# %%
# creating two arrays x and y
x = np.linspace(0, 5, 11)
y = x * 2

# %%
#Plotting a linegraph
plt.plot(x, y)
plt.title('Basic example pf title')
plt.xlabel('botton label')
plt.ylabel('right label')
# Out:
# Text(0, 0.5, 'right label')

# %%
#sub plot
plt.subplot(2,2,1)

plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
#Use of figure in matplotlib
figure = plt.figure(figsize=(10,6), dpi=100)
axes1 = figure.add_axes([0.2, 0.2, 1,1])
axes1.plot(x, y)
axes2 = figure.add_axes([0.1, 0.1, .8,.8])
axes2.plot(x**2,y)

# %%
#Scatter plot
plt.scatter(x**2, y)

# %%
#Histogram
data = np.random.randint(100, size = 80)
plt.hist(data)
# Out:
# (array([ 8.,  9.,  5., 10.,  6.,  8.,  7.,  9.,  7., 11.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
#boxplot
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x173676ad0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x173676d50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x173676990>],
#  'medians': [<matplotlib.lines.Line2D at 0x173676fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x173677110>],
#  'means': []}

# %%
#saving custom plots
#for saving plots you should use the figure to create a plot and save it using plt.save_fig('.png')

# %%
'''fig1, axs1 = plt.subplots()
axs1.hist(data)
fig1.savefig('data.png')'''
# Out:
# "fig1, axs1 = plt.subplots()\naxs1.hist(data)\nfig1.savefig('data.png')"

# %% [markdown]
# Practising seaborn

# %%
#importing seaborn
import seaborn as sns

# %%
df
# Out:
#     Rank  Peak  All Time Peak  Actual_Gross  Adjusted gross (in 2022 dollars)  \
# 0      1     1              2     780000000                         780000000
# 1      2     1              7     579800000                         579800000
# 2      3     1              2     411000000                         560622615
# 3      4     2             10     397300000                         454751555
# 4      5     2              8     345675146                         402844849
# 5      6     2             10     305158363                         388978496
# 6      7     2              8     280000000                         381932682
# 7      7     2              8     257600000                         257600000
# 8      9     2              8     256084556                         312258401
# 9     10     2              8     250400000                         309141878
# 10    11     2              8     229100000                         283202896
# ...

# %%
#distribution plot using sns
sns.displot(data = data)
